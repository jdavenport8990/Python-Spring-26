# %% [markdown]
# <a href="https://colab.research.google.com/github/jdavenport8990/Python-Spring-26/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Statements

#Import Definitions

#Import program logic

#Assign value to variables: name, goal, birth_year, current_year

#Calculate age

#Print top border

#Print bio sentence

#Print bottom border
