# %% [markdown]
# <a href="https://colab.research.google.com/github/jdavenport8990/Python-Spring-26/blob/main/Week14/Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS

# CLASS DEFINITIONS

#Create a class named Book:
class Book:

#Method __init__ (self, title, author)
    def __init__(self, title, author):
        self.title = title
        self.author = author
#set is_available to True by default
        self.is_available = True

#method __str__(self):
    def __str__(self):
    #if is_available is True, return "title by author - Available"
        if self.is_available:
            return f"{self.title} by {self.author} - Available"
#Otherwise return "title by author-Checked out"
        else:
            return f"{self.title} by {self.author} - Checked Out"




#method checkout()
    def checkout(self):
#is_available to False
        self.is_available = False



#Method return_book()
    def return_book(self):
#is_available to True
        self.is_available = True

# PROGRAM LOGIC

#Instance #1 (objects) of the Book class
my_book = Book("Pet Sematary" , "Stephen King")
#Instance #2 of the Book class
my_book2 = Book("The Last Time I Was Me", "Cathy Lamb")

#Print the status of both books
print("***** Library Status *****")
print(my_book)
print(my_book2)


#"Check out" one of the books using your method.
print("\n***** Check Out 'Pet Sematary' *****\n")
my_book.checkout()
my_book2.checkout()

#Return one of the books
print("\n***** Return 'The Last Time I Was Me' *****\n")
my_book2.return_book()


#Print both books again to show that the status of the specific object has changed.
print("***** Updated Status *****")
print(my_book)
print(my_book2)
# Out:
# ***** Library Status *****
# Pet Sematary by Stephen King - Available
# The Last Time I Was Me by Cathy Lamb - Available
#
# ***** Check Out 'Pet Sematary' *****
#
#
# ***** Return 'The Last Time I Was Me' *****
#
# ***** Updated Status *****
# Pet Sematary by Stephen King - Checked Out
# The Last Time I Was Me by Cathy Lamb - Available
