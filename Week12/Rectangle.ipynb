# %% [markdown]
# <a href="https://colab.research.google.com/github/jdavenport8990/Python-Spring-26/blob/main/Week12/Rectangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rectangle.py
# IMPORT STATEMENTS #

# FUNCTION DEFINITIONS #

#Define function calculate_rectangle(length, width)
def calculate_rectangle(length, width):

#Calculate area(length * width)
    area = length * width

#Calculate perimeter(length*width) * 2
    perimeter = (length * width) * 2

#Return area and perimeter as a tupule
    return area, perimeter




# PROGRAM LOGIC #

#Ask the user to input a length and a width (convert these to floats).
length = float(input("Enter the length: "))
width = float(input("Enter the width of the: "))

#Unpack the returned tuple into two separate variables called my_area and my_perimeter.
my_area, my_perimeter = calculate_rectangle(length, width)

#Print the results clearly for the user.
print("**** Results ****")
print("The area of the rectangle is: ", my_area)
print("The perimeter of the rectangle is: ", my_perimeter)
# Out:
# Enter the length: 20
# Enter the width of the: 24
# **** Results ****
# The area of the rectangle is:  480.0
# The perimeter of the rectangle is:  960.0
