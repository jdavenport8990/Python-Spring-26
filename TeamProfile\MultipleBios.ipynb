# %% [markdown]
# <a href="https://colab.research.google.com/github/jdavenport8990/Python-Spring-26/blob/main/TeamProfile%5CMultipleBios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
  print("Name: " + name +  " Age: " + str(age) + " Goal: " + goal)

# 2. Inside the function, use string multiplication (*) for a border line.
  print("*" * 40)
# 3. Print the bio details using the parameter names.

# PROGRAM LOGIC
# 1. Call print_bio using my own info. Jessica, Age: 36 Goal: Learn Python
# 2. Call print_bio using [Issa rae, 41, Producer].
# 3. Call print_bio using [Purple Rayne, 25, Astronomer].
print_bio("Jessica", 36, "Learn Python")
# Out:
# Name: Jessica Age: 36 Goal: Learn Python
# ****************************************
