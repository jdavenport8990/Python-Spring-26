# %% [markdown]
# <a href="https://colab.research.google.com/github/jdavenport8990/Python-Spring-26/blob/main/Week9/WeekRentalCar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rentalcar.py
# IMPORT STATEMENTS#

# FUNCTION DEFINITIONS #

#Function1: car_classificationCode
def car_classificationCode(code):

#Renter must enter B, S, or L
    if code == 'B' or code == 'S' or code == 'L':
        return True

#Must return True or False
    else:
        return False


#Function2: calculate_miles_driven(total_miles)
def calculate_miles_driven(start, end):
    return end - start

#Calculate charged miles
def calculate_charged_miles(total_miles):


#if total_miles_driven > 100 then return total_miles_driven - 100
    if total_miles > 100:
        return total_miles - 100


#Otherwise return 0
    else:
        return 0

#Function 3: Calculate_bill(code, amount of days, charged miles) Remeber no print statements!
def calculate_bill(code, days, miles):
#Use classification code to calculate daily rate
#Calculate total bill
    return 0

# PROGRAM LOGIC#

#Ask renter for car classification
code = input("Enter car classification code (B, S, L): ")
while not car_classificationCode(code):
    print("Invalid classification code. Please enter B, S, L.")
    code = input("Enter car classification code (B, S, L): ")

#Ask for start and ending odometer reading
start_odometer = int(input("Enter start odometer reading: "))
end_odometer = int(input("Enter end odometer reading: "))

#Ask for number of days rented
days_rented = int(input("Enter number of days: "))

#Calculate  total number of miles driven
total_miles = calculate_miles_driven(start_odometer, end_odometer)

#Calculate amount of miles renter will be charged for
Charged_miles = calculate_charged_miles(total_miles)

#Call calculate_bill and store the returned amount
#Print the total amount

print("classification:", code)
print("total miles driven:", total_miles)
print("charged miles:", Charged_miles)
# Out:
# Enter car classification code (B, S, L): l
# Invalid classification code. Please enter B, S, L.
# Enter car classification code (B, S, L): L
# Enter start odometer reading: 200
# Enter end odometer reading: 600
# Enter number of days: 5
# classification: L
# total miles driven: 400
# charged miles: 300
