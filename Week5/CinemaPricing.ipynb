# %% [markdown]
# <a href="https://colab.research.google.com/github/jdavenport8990/Python-Spring-26/blob/main/Week5/CinemaPricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)


def calculate_ticket(age, hour):


    # 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
    if age <= 12 or age >= 65:
        price = 8
    else:
        price = 12


    # 3. Logic: If hour < 17, subtract 2 from the price.
    if hour < 17:
        price -= 2


# 4. Return the final price.
        return price

# 4. Print the final price.

# PROGRAM LOGIC
# 1. input() for age (int)
age = int(input("Enter your age: "))


# 2. input() for movie hour (int)
hour = int(input("Enter the movie hour (0-23): "))

# 3. Call calculate_ticket()
price = calculate_ticket(age, hour)

# 4. Print the final price.
print("The ticket price is:", price)
# Out:
# Enter your age: 35
# Enter the movie hour (0-23): 10
# The ticket price is: 10
